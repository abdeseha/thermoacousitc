# %%
from openpyxl import Workbook, load_workbook
import numpy as np
import matplotlib.pyplot as plt

book = load_workbook('try.xlsx', data_only=True)
sheet = book['Conso Broyage 10_35kg']

P_list = []
t = []

for  j, p in enumerate(sheet['E']):
    try:
        p = float(p.value)
        P_list.append(p * 400)
        t.append(float(sheet['A' + str(j+1)].value))
    except:
        continue

# %%
plt.plot(t,P_list,color='c',linewidth=1.5,label='Noisy')
#plt.xlim(t[0],t[-1])
plt.legend()
plt.show()

# %%
Pf = np.fft.fft(P_list)
PDS = np.absolute(Pf)

# indeces = PDS >= 0.5* np.max(PDS)
# Pf = indeces * Pf
P_list = np.absolute(np.fft.ifft(Pf))
plt.plot(t,P_list,color='c',linewidth=1.5,label='Noisy')
plt.legend()
plt.show()
